# %%
from nba_api.stats.endpoints import playercareerstats
from nba_api.live.nba.endpoints import scoreboard
import pandas as pd
from pprint import pprint

# Nikola Jokić
career = playercareerstats.PlayerCareerStats(player_id='203999') 

# pandas data frames (optional: pip install pandas)
career.get_data_frames()[0]

# json
#pprint(career.get_json())

# dictionary
pprint(career.get_dict())

# %%
# Extract the relevant data from the API response
data = career.get_data_frames()[0]

# Create a DataFrame
df = pd.DataFrame(data)

# Display the DataFrame
df
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     203999   2015-16        00  1610612743               DEN        21.0
# 1     203999   2016-17        00  1610612743               DEN        22.0
# 2     203999   2017-18        00  1610612743               DEN        23.0
# 3     203999   2018-19        00  1610612743               DEN        24.0
# 4     203999   2019-20        00  1610612743               DEN        25.0
# 5     203999   2020-21        00  1610612743               DEN        26.0
# 6     203999   2021-22        00  1610612743               DEN        27.0
# 7     203999   2022-23        00  1610612743               DEN        28.0
# 8     203999   2023-24        00  1610612743               DEN        28.0
#
#    GP  GS     MIN  FGM  ...  FT_PCT  OREB  DREB   REB  AST  STL  BLK  TOV  \
# 0  80  55  1733.0  307  ...   0.811   181   379   560  189   79   50  104
# 1  73  59  2038.0  494  ...   0.825   212   506   718  359   61   55  171
# 2  75  73  2443.0  504  ...   0.850   195   608   803  458   90   61  210
# 3  80  80  2504.0  616  ...   0.821   228   637   865  580  108   55  248
# 4  73  73  2335.0  565  ...   0.817   166   545   711  512   85   44  226
# 5  72  72  2488.0  732  ...   0.868   205   575   780  599   95   48  222
# 6  74  74  2476.0  764  ...   0.810   206   813  1019  584  109   63  281
# 7  69  69  2323.0  646  ...   0.822   167   650   817  678   87   47  247
# 8  10  10   346.0  120  ...   0.754    34   103   137   83   10    8   34
#
#     PF   PTS
# 0  208   796
# 1  214  1221
# 2  212  1385
# 3  228  1604
# 4  222  1456
# 5  192  1898
# 6  191  2004
# 7  174  1690
# 8   22   298
#
# [9 rows x 27 columns]

# %%
# Today's Score Board
games = scoreboard.ScoreBoard()

# json
#games.get_json()

# dictionary
pprint(games.get_dict())
# Out:
# {'meta': {'code': 200,
#           'request': 'https://nba-prod-us-east-1-mediaops-stats.s3.amazonaws.com/NBA/liveData/scoreboard/todaysScoreboard_00.json',
#           'time': '2023-11-14 05:16:31.1631',
#           'version': 1},
#  'scoreboard': {'gameDate': '2023-11-14',
#                 'games': [{'awayTeam': {'inBonus': None,
#                                         'losses': 4,
#                                         'periods': [{'period': 1,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 2,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 3,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 4,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0}],
#                                         'score': 0,
#                                         'seed': None,
#                                         'teamCity': 'Miami',
#                                         'teamId': 1610612748,
#                                         'teamName': 'Heat',
#                                         'teamTricode': 'MIA',
#                                         'timeoutsRemaining': 0,
#                                         'wins': 6},
#                            'gameClock': '',
#                            'gameCode': '20231114/MIACHA',
#                            'gameEt': '2023-11-14T19:00:00Z',
#                            'gameId': '0022300017',
#                            'gameLeaders': {'awayLeaders': {'assists': 0,
#                                                            'jerseyNum': '',
#                                                            'name': '',
#                                                            'personId': 0,
#                                                            'playerSlug': None,
#                                                            'points': 0,
#                                                            'position': '',
#                                                            'rebounds': 0,
#                                                            'teamTricode': 'MIA'},
#                                            'homeLeaders': {'assists': 0,
#                                                            'jerseyNum': '',
#                                                            'name': '',
#                                                            'personId': 0,
#                                                            'playerSlug': None,
#                                                            'points': 0,
#                                                            'position': '',
#                                                            'rebounds': 0,
#                                                            'teamTricode': 'CHA'}},
#                            'gameStatus': 1,
#                            'gameStatusText': '7:00 pm ET',
#                            'gameSubtype': 'in-season',
#                            'gameTimeUTC': '2023-11-15T00:00:00Z',
#                            'homeTeam': {'inBonus': None,
#                                         'losses': 6,
#                                         'periods': [{'period': 1,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 2,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 3,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 4,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0}],
#                                         'score': 0,
#                                         'seed': None,
#                                         'teamCity': 'Charlotte',
#                                         'teamId': 1610612766,
#                                         'teamName': 'Hornets',
#                                         'teamTricode': 'CHA',
#                                         'timeoutsRemaining': 0,
#                                         'wins': 3},
#                            'ifNecessary': False,
#                            'pbOdds': {'odds': 0.0,
#                                       'suspended': 0,
#                                       'team': None},
#                            'period': 0,
#                            'poRoundDesc': '',
#                            'regulationPeriods': 4,
#                            'seriesConference': '',
#                            'seriesGameNumber': '',
#                            'seriesText': 'East Group B'},
#                           {'awayTeam': {'inBonus': None,
#                                         'losses': 4,
#                                         'periods': [{'period': 1,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 2,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 3,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 4,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0}],
#                                         'score': 0,
#                                         'seed': None,
#                                         'teamCity': 'Atlanta',
#                                         'teamId': 1610612737,
#                                         'teamName': 'Hawks',
#                                         'teamTricode': 'ATL',
#                                         'timeoutsRemaining': 0,
#                                         'wins': 5},
#                            'gameClock': '',
#                            'gameCode': '20231114/ATLDET',
#                            'gameEt': '2023-11-14T19:00:00Z',
#                            'gameId': '0022300018',
#                            'gameLeaders': {'awayLeaders': {'assists': 0,
#                                                            'jerseyNum': '',
#                                                            'name': '',
#                                                            'personId': 0,
#                                                            'playerSlug': None,
#                                                            'points': 0,
#                                                            'position': '',
#                                                            'rebounds': 0,
#                                                            'teamTricode': 'ATL'},
#                                            'homeLeaders': {'assists': 0,
#                                                            'jerseyNum': '',
#                                                            'name': '',
#                                                            'personId': 0,
#                                                            'playerSlug': None,
#                                                            'points': 0,
#                                                            'position': '',
#                                                            'rebounds': 0,
#                                                            'teamTricode': 'DET'}},
#                            'gameStatus': 1,
#                            'gameStatusText': '7:00 pm ET',
#                            'gameSubtype': 'in-season',
#                            'gameTimeUTC': '2023-11-15T00:00:00Z',
#                            'homeTeam': {'inBonus': None,
#                                         'losses': 9,
#                                         'periods': [{'period': 1,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 2,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 3,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 4,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0}],
#                                         'score': 0,
#                                         'seed': None,
#                                         'teamCity': 'Detroit',
#                                         'teamId': 1610612765,
#                                         'teamName': 'Pistons',
#                                         'teamTricode': 'DET',
#                                         'timeoutsRemaining': 0,
#                                         'wins': 2},
#                            'ifNecessary': False,
#                            'pbOdds': {'odds': 0.0,
#                                       'suspended': 0,
#                                       'team': None},
#                            'period': 0,
#                            'poRoundDesc': '',
#                            'regulationPeriods': 4,
#                            'seriesConference': '',
#                            'seriesGameNumber': '',
#                            'seriesText': 'East Group A'},
#                           {'awayTeam': {'inBonus': None,
#                                         'losses': 4,
#                                         'periods': [{'period': 1,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 2,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 3,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 4,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0}],
#                                         'score': 0,
#                                         'seed': None,
#                                         'teamCity': 'Indiana',
#                                         'teamId': 1610612754,
#                                         'teamName': 'Pacers',
#                                         'teamTricode': 'IND',
#                                         'timeoutsRemaining': 0,
#                                         'wins': 6},
#                            'gameClock': '',
#                            'gameCode': '20231114/INDPHI',
#                            'gameEt': '2023-11-14T19:00:00Z',
#                            'gameId': '0022300019',
#                            'gameLeaders': {'awayLeaders': {'assists': 0,
#                                                            'jerseyNum': '',
#                                                            'name': '',
#                                                            'personId': 0,
#                                                            'playerSlug': None,
#                                                            'points': 0,
#                                                            'position': '',
#                                                            'rebounds': 0,
#                                                            'teamTricode': 'IND'},
#                                            'homeLeaders': {'assists': 0,
#                                                            'jerseyNum': '',
#                                                            'name': '',
#                                                            'personId': 0,
#                                                            'playerSlug': None,
#                                                            'points': 0,
#                                                            'position': '',
#                                                            'rebounds': 0,
#                                                            'teamTricode': 'PHI'}},
#                            'gameStatus': 1,
#                            'gameStatusText': '7:00 pm ET',
#                            'gameSubtype': 'in-season',
#                            'gameTimeUTC': '2023-11-15T00:00:00Z',
#                            'homeTeam': {'inBonus': None,
#                                         'losses': 1,
#                                         'periods': [{'period': 1,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 2,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 3,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 4,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0}],
#                                         'score': 0,
#                                         'seed': None,
#                                         'teamCity': 'Philadelphia',
#                                         'teamId': 1610612755,
#                                         'teamName': '76ers',
#                                         'teamTricode': 'PHI',
#                                         'timeoutsRemaining': 0,
#                                         'wins': 8},
#                            'ifNecessary': False,
#                            'pbOdds': {'odds': 0.0,
#                                       'suspended': 0,
#                                       'team': None},
#                            'period': 0,
#                            'poRoundDesc': '',
#                            'regulationPeriods': 4,
#                            'seriesConference': '',
#                            'seriesGameNumber': '',
#                            'seriesText': 'East Group A'},
#                           {'awayTeam': {'inBonus': None,
#                                         'losses': 4,
#                                         'periods': [{'period': 1,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 2,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 3,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 4,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0}],
#                                         'score': 0,
#                                         'seed': None,
#                                         'teamCity': 'Orlando',
#                                         'teamId': 1610612753,
#                                         'teamName': 'Magic',
#                                         'teamTricode': 'ORL',
#                                         'timeoutsRemaining': 0,
#                                         'wins': 5},
#                            'gameClock': '',
#                            'gameCode': '20231114/ORLBKN',
#                            'gameEt': '2023-11-14T19:30:00Z',
#                            'gameId': '0022300020',
#                            'gameLeaders': {'awayLeaders': {'assists': 0,
#                                                            'jerseyNum': '',
#                                                            'name': '',
#                                                            'personId': 0,
#                                                            'playerSlug': None,
#                                                            'points': 0,
#                                                            'position': '',
#                                                            'rebounds': 0,
#                                                            'teamTricode': 'ORL'},
#                                            'homeLeaders': {'assists': 0,
#                                                            'jerseyNum': '',
#                                                            'name': '',
#                                                            'personId': 0,
#                                                            'playerSlug': None,
#                                                            'points': 0,
#                                                            'position': '',
#                                                            'rebounds': 0,
#                                                            'teamTricode': 'BKN'}},
#                            'gameStatus': 1,
#                            'gameStatusText': '7:30 pm ET',
#                            'gameSubtype': 'in-season',
#                            'gameTimeUTC': '2023-11-15T00:30:00Z',
#                            'homeTeam': {'inBonus': None,
#                                         'losses': 5,
#                                         'periods': [{'period': 1,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 2,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 3,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 4,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0}],
#                                         'score': 0,
#                                         'seed': None,
#                                         'teamCity': 'Brooklyn',
#                                         'teamId': 1610612751,
#                                         'teamName': 'Nets',
#                                         'teamTricode': 'BKN',
#                                         'timeoutsRemaining': 0,
#                                         'wins': 5},
#                            'ifNecessary': False,
#                            'pbOdds': {'odds': 0.0,
#                                       'suspended': 0,
#                                       'team': None},
#                            'period': 0,
#                            'poRoundDesc': '',
#                            'regulationPeriods': 4,
#                            'seriesConference': '',
#                            'seriesGameNumber': '',
#                            'seriesText': 'East Group C'},
#                           {'awayTeam': {'inBonus': None,
#                                         'losses': 7,
#                                         'periods': [{'period': 1,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 2,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 3,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 4,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0}],
#                                         'score': 0,
#                                         'seed': None,
#                                         'teamCity': 'San Antonio',
#                                         'teamId': 1610612759,
#                                         'teamName': 'Spurs',
#                                         'teamTricode': 'SAS',
#                                         'timeoutsRemaining': 0,
#                                         'wins': 3},
#                            'gameClock': '',
#                            'gameCode': '20231114/SASOKC',
#                            'gameEt': '2023-11-14T19:30:00Z',
#                            'gameId': '0022300021',
#                            'gameLeaders': {'awayLeaders': {'assists': 0,
#                                                            'jerseyNum': '',
#                                                            'name': '',
#                                                            'personId': 0,
#                                                            'playerSlug': None,
#                                                            'points': 0,
#                                                            'position': '',
#                                                            'rebounds': 0,
#                                                            'teamTricode': 'SAS'},
#                                            'homeLeaders': {'assists': 0,
#                                                            'jerseyNum': '',
#                                                            'name': '',
#                                                            'personId': 0,
#                                                            'playerSlug': None,
#                                                            'points': 0,
#                                                            'position': '',
#                                                            'rebounds': 0,
#                                                            'teamTricode': 'OKC'}},
#                            'gameStatus': 1,
#                            'gameStatusText': '7:30 pm ET',
#                            'gameSubtype': 'in-season',
#                            'gameTimeUTC': '2023-11-15T00:30:00Z',
#                            'homeTeam': {'inBonus': None,
#                                         'losses': 4,
#                                         'periods': [{'period': 1,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 2,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 3,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 4,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0}],
#                                         'score': 0,
#                                         'seed': None,
#                                         'teamCity': 'Oklahoma City',
#                                         'teamId': 1610612760,
#                                         'teamName': 'Thunder',
#                                         'teamTricode': 'OKC',
#                                         'timeoutsRemaining': 0,
#                                         'wins': 6},
#                            'ifNecessary': False,
#                            'pbOdds': {'odds': 0.0,
#                                       'suspended': 0,
#                                       'team': None},
#                            'period': 0,
#                            'poRoundDesc': '',
#                            'regulationPeriods': 4,
#                            'seriesConference': '',
#                            'seriesGameNumber': '',
#                            'seriesText': 'West Group C'},
#                           {'awayTeam': {'inBonus': None,
#                                         'losses': 2,
#                                         'periods': [{'period': 1,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 2,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 3,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 4,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0}],
#                                         'score': 0,
#                                         'seed': None,
#                                         'teamCity': 'Dallas',
#                                         'teamId': 1610612742,
#                                         'teamName': 'Mavericks',
#                                         'teamTricode': 'DAL',
#                                         'timeoutsRemaining': 0,
#                                         'wins': 8},
#                            'gameClock': '',
#                            'gameCode': '20231114/DALNOP',
#                            'gameEt': '2023-11-14T20:00:00Z',
#                            'gameId': '0022300022',
#                            'gameLeaders': {'awayLeaders': {'assists': 0,
#                                                            'jerseyNum': '',
#                                                            'name': '',
#                                                            'personId': 0,
#                                                            'playerSlug': None,
#                                                            'points': 0,
#                                                            'position': '',
#                                                            'rebounds': 0,
#                                                            'teamTricode': 'DAL'},
#                                            'homeLeaders': {'assists': 0,
#                                                            'jerseyNum': '',
#                                                            'name': '',
#                                                            'personId': 0,
#                                                            'playerSlug': None,
#                                                            'points': 0,
#                                                            'position': '',
#                                                            'rebounds': 0,
#                                                            'teamTricode': 'NOP'}},
#                            'gameStatus': 1,
#                            'gameStatusText': '8:00 pm ET',
#                            'gameSubtype': 'in-season',
#                            'gameTimeUTC': '2023-11-15T01:00:00Z',
#                            'homeTeam': {'inBonus': None,
#                                         'losses': 6,
#                                         'periods': [{'period': 1,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 2,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 3,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 4,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0}],
#                                         'score': 0,
#                                         'seed': None,
#                                         'teamCity': 'New Orleans',
#                                         'teamId': 1610612740,
#                                         'teamName': 'Pelicans',
#                                         'teamTricode': 'NOP',
#                                         'timeoutsRemaining': 0,
#                                         'wins': 4},
#                            'ifNecessary': False,
#                            'pbOdds': {'odds': 0.0,
#                                       'suspended': 0,
#                                       'team': None},
#                            'period': 0,
#                            'poRoundDesc': '',
#                            'regulationPeriods': 4,
#                            'seriesConference': '',
#                            'seriesGameNumber': '',
#                            'seriesText': 'West Group B'},
#                           {'awayTeam': {'inBonus': None,
#                                         'losses': 6,
#                                         'periods': [{'period': 1,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 2,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 3,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 4,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0}],
#                                         'score': 0,
#                                         'seed': None,
#                                         'teamCity': 'Portland',
#                                         'teamId': 1610612757,
#                                         'teamName': 'Trail Blazers',
#                                         'teamTricode': 'POR',
#                                         'timeoutsRemaining': 0,
#                                         'wins': 3},
#                            'gameClock': '',
#                            'gameCode': '20231114/PORUTA',
#                            'gameEt': '2023-11-14T21:00:00Z',
#                            'gameId': '0022300023',
#                            'gameLeaders': {'awayLeaders': {'assists': 0,
#                                                            'jerseyNum': '',
#                                                            'name': '',
#                                                            'personId': 0,
#                                                            'playerSlug': None,
#                                                            'points': 0,
#                                                            'position': '',
#                                                            'rebounds': 0,
#                                                            'teamTricode': 'POR'},
#                                            'homeLeaders': {'assists': 0,
#                                                            'jerseyNum': '',
#                                                            'name': '',
#                                                            'personId': 0,
#                                                            'playerSlug': None,
#                                                            'points': 0,
#                                                            'position': '',
#                                                            'rebounds': 0,
#                                                            'teamTricode': 'UTA'}},
#                            'gameStatus': 1,
#                            'gameStatusText': '9:00 pm ET',
#                            'gameSubtype': 'in-season',
#                            'gameTimeUTC': '2023-11-15T02:00:00Z',
#                            'homeTeam': {'inBonus': None,
#                                         'losses': 7,
#                                         'periods': [{'period': 1,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 2,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 3,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 4,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0}],
#                                         'score': 0,
#                                         'seed': None,
#                                         'teamCity': 'Utah',
#                                         'teamId': 1610612762,
#                                         'teamName': 'Jazz',
#                                         'teamTricode': 'UTA',
#                                         'timeoutsRemaining': 0,
#                                         'wins': 3},
#                            'ifNecessary': False,
#                            'pbOdds': {'odds': 0.0,
#                                       'suspended': 0,
#                                       'team': None},
#                            'period': 0,
#                            'poRoundDesc': '',
#                            'regulationPeriods': 4,
#                            'seriesConference': '',
#                            'seriesGameNumber': '',
#                            'seriesText': 'West Group A'},
#                           {'awayTeam': {'inBonus': None,
#                                         'losses': 6,
#                                         'periods': [{'period': 1,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 2,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 3,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 4,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0}],
#                                         'score': 0,
#                                         'seed': None,
#                                         'teamCity': 'LA',
#                                         'teamId': 1610612746,
#                                         'teamName': 'Clippers',
#                                         'teamTricode': 'LAC',
#                                         'timeoutsRemaining': 0,
#                                         'wins': 3},
#                            'gameClock': '',
#                            'gameCode': '20231114/LACDEN',
#                            'gameEt': '2023-11-14T22:00:00Z',
#                            'gameId': '0022300024',
#                            'gameLeaders': {'awayLeaders': {'assists': 0,
#                                                            'jerseyNum': '',
#                                                            'name': '',
#                                                            'personId': 0,
#                                                            'playerSlug': None,
#                                                            'points': 0,
#                                                            'position': '',
#                                                            'rebounds': 0,
#                                                            'teamTricode': 'LAC'},
#                                            'homeLeaders': {'assists': 0,
#                                                            'jerseyNum': '',
#                                                            'name': '',
#                                                            'personId': 0,
#                                                            'playerSlug': None,
#                                                            'points': 0,
#                                                            'position': '',
#                                                            'rebounds': 0,
#                                                            'teamTricode': 'DEN'}},
#                            'gameStatus': 1,
#                            'gameStatusText': '10:00 pm ET',
#                            'gameSubtype': 'in-season',
#                            'gameTimeUTC': '2023-11-15T03:00:00Z',
#                            'homeTeam': {'inBonus': None,
#                                         'losses': 2,
#                                         'periods': [{'period': 1,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 2,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 3,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 4,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0}],
#                                         'score': 0,
#                                         'seed': None,
#                                         'teamCity': 'Denver',
#                                         'teamId': 1610612743,
#                                         'teamName': 'Nuggets',
#                                         'teamTricode': 'DEN',
#                                         'timeoutsRemaining': 0,
#                                         'wins': 8},
#                            'ifNecessary': False,
#                            'pbOdds': {'odds': 0.0,
#                                       'suspended': 0,
#                                       'team': None},
#                            'period': 0,
#                            'poRoundDesc': '',
#                            'regulationPeriods': 4,
#                            'seriesConference': '',
#                            'seriesGameNumber': '',
#                            'seriesText': 'West Group B'},
#                           {'awayTeam': {'inBonus': None,
#                                         'losses': 2,
#                                         'periods': [{'period': 1,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 2,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 3,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 4,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0}],
#                                         'score': 0,
#                                         'seed': None,
#                                         'teamCity': 'Minnesota',
#                                         'teamId': 1610612750,
#                                         'teamName': 'Timberwolves',
#                                         'teamTricode': 'MIN',
#                                         'timeoutsRemaining': 0,
#                                         'wins': 7},
#                            'gameClock': '',
#                            'gameCode': '20231114/MINGSW',
#                            'gameEt': '2023-11-14T22:00:00Z',
#                            'gameId': '0022300025',
#                            'gameLeaders': {'awayLeaders': {'assists': 0,
#                                                            'jerseyNum': '',
#                                                            'name': '',
#                                                            'personId': 0,
#                                                            'playerSlug': None,
#                                                            'points': 0,
#                                                            'position': '',
#                                                            'rebounds': 0,
#                                                            'teamTricode': 'MIN'},
#                                            'homeLeaders': {'assists': 0,
#                                                            'jerseyNum': '',
#                                                            'name': '',
#                                                            'personId': 0,
#                                                            'playerSlug': None,
#                                                            'points': 0,
#                                                            'position': '',
#                                                            'rebounds': 0,
#                                                            'teamTricode': 'GSW'}},
#                            'gameStatus': 1,
#                            'gameStatusText': '10:00 pm ET',
#                            'gameSubtype': 'in-season',
#                            'gameTimeUTC': '2023-11-15T03:00:00Z',
#                            'homeTeam': {'inBonus': None,
#                                         'losses': 5,
#                                         'periods': [{'period': 1,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 2,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 3,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 4,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0}],
#                                         'score': 0,
#                                         'seed': None,
#                                         'teamCity': 'Golden State',
#                                         'teamId': 1610612744,
#                                         'teamName': 'Warriors',
#                                         'teamTricode': 'GSW',
#                                         'timeoutsRemaining': 0,
#                                         'wins': 6},
#                            'ifNecessary': False,
#                            'pbOdds': {'odds': 0.0,
#                                       'suspended': 0,
#                                       'team': None},
#                            'period': 0,
#                            'poRoundDesc': '',
#                            'regulationPeriods': 4,
#                            'seriesConference': '',
#                            'seriesGameNumber': '',
#                            'seriesText': 'West Group C'},
#                           {'awayTeam': {'inBonus': None,
#                                         'losses': 8,
#                                         'periods': [{'period': 1,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 2,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 3,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 4,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0}],
#                                         'score': 0,
#                                         'seed': None,
#                                         'teamCity': 'Memphis',
#                                         'teamId': 1610612763,
#                                         'teamName': 'Grizzlies',
#                                         'teamTricode': 'MEM',
#                                         'timeoutsRemaining': 0,
#                                         'wins': 2},
#                            'gameClock': '',
#                            'gameCode': '20231114/MEMLAL',
#                            'gameEt': '2023-11-14T22:30:00Z',
#                            'gameId': '0022300026',
#                            'gameLeaders': {'awayLeaders': {'assists': 0,
#                                                            'jerseyNum': '',
#                                                            'name': '',
#                                                            'personId': 0,
#                                                            'playerSlug': None,
#                                                            'points': 0,
#                                                            'position': '',
#                                                            'rebounds': 0,
#                                                            'teamTricode': 'MEM'},
#                                            'homeLeaders': {'assists': 0,
#                                                            'jerseyNum': '',
#                                                            'name': '',
#                                                            'personId': 0,
#                                                            'playerSlug': None,
#                                                            'points': 0,
#                                                            'position': '',
#                                                            'rebounds': 0,
#                                                            'teamTricode': 'LAL'}},
#                            'gameStatus': 1,
#                            'gameStatusText': '10:30 pm ET',
#                            'gameSubtype': 'in-season',
#                            'gameTimeUTC': '2023-11-15T03:30:00Z',
#                            'homeTeam': {'inBonus': None,
#                                         'losses': 5,
#                                         'periods': [{'period': 1,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 2,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 3,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0},
#                                                     {'period': 4,
#                                                      'periodType': 'REGULAR',
#                                                      'score': 0}],
#                                         'score': 0,
#                                         'seed': None,
#                                         'teamCity': 'Los Angeles',
#                                         'teamId': 1610612747,
#                                         'teamName': 'Lakers',
#                                         'teamTricode': 'LAL',
#                                         'timeoutsRemaining': 0,
#                                         'wins': 5},
#                            'ifNecessary': False,
#                            'pbOdds': {'odds': 0.0,
#                                       'suspended': 0,
#                                       'team': None},
#                            'period': 0,
#                            'poRoundDesc': '',
#                            'regulationPeriods': 4,
#                            'seriesConference': '',
#                            'seriesGameNumber': '',
#                            'seriesText': 'West Group A'}],
#                 'leagueId': '00',
#                 'leagueName': 'National Basketball Association'}}
